# %%
import os
import sox
import random
from glob import glob
from tqdm import tqdm
from IPython.display import Audio

# %%
Audio('/Users/quangbd/Documents/data/kws-data/viet_nam_20201103/viet_bac/0005890_0.wav', autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
os.remove('/Users/quangbd/Documents/data/kws-data/viet_nam_20201103/viet/62388_0.wav')
